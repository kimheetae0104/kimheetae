# %% [markdown]
# 파이썬

# %%
1+3 #주석처리!

# %%
print(5)

# %%
num=3
print(num)

# %%
str1 = str2 = 'python'
print(str1)
print(str2)

# %% [markdown]
# # x = 100
# y = 200
# sum = 300
# print(sum)

# %%
str1 = "she's gone"
print(str1)

# %%
s = 'she\'s gone'
print(s)

# %%
s1 = "자세히 보아야 예쁘다\n 오래보아야 사랑스럽다 \n 너도 그렇다"
print(s1)

# %%
#개행 \n 또는 """문자열"""
s1 = """자세히 보아야 예쁘다. 오래보아야 사랑스럽다. 너도 그렇다"""
print(s1)

# %% [markdown]
# 인덱싱

# %%
name = 'My name is kim'
print(name[3])

# %%
name = 'My name is kim'
print(name[8])

# %%
print(name[11:13])
print(name[3:7])
print(name[-11:-6])
print(name[:])

# %%
print(name[-11:])

# %%
day = '2021년 12월 21일의 날씨는 맑음입니다'
#날짜 : 2021년 12월 21일
#날씨 : 맑음
print('날짜 :' ,day[:13])
print('날씨 :' ,day[19:21])

# %%
s = 2021+'년

# %%
#오늘은 12월 21일 입니다
day = 22
s = '오늘은 12월 %d일 입니다.'%day
print(s)

# %%
s = '오늘은 12월 {}일 입니다.' .format(day)
print(s)

# %%
s = f'오늘은 12월 {day}일 입니다.' 
print(s)

# %%
x = 100
y = 200
sum2 = x + y
print('{}와 {}의 합은 {}입니다.'.format(x,y,sum2))  
print('%d와 %d는 합은 %d 입니다.'%(x,y,sum2))
print(f'{x}와 {y}의 합은 {sum2}입니다.')

# %% [markdown]
# ![%ED%8C%8C%EC%9D%B4%EC%8D%AC1.png](attachment:%ED%8C%8C%EC%9D%B4%EC%8D%AC1.png)

# %% [markdown]
# ![%ED%8C%8C%EC%9D%B4%EC%8D%AC1.png](attachment:%ED%8C%8C%EC%9D%B4%EC%8D%AC1.png)

# %% [markdown]
# ## 산술연산자

# %%
num1 = 10
num2 = 7
#나누기 
#나머지
#몫
print(num1/num2)
print(num1%num2)
print(num1//num2)

# %%
print(num1+num2)

# %%
str1 = "누구"
str2 = "세요"
print(str1 + str2)

# %%
#형이 다르면 연산이 안된다 
#강제 형변환을 시켜주면 된다
str1 = "10"
num3 = 7
print(int(str1)+num3)
print(str1+str(num3))

# %%
num1 =23
num2 = 3

# %%
print(num1)

# %%
num1 = 23
num2 = 3
print('더하기 결과 : %d'%(num1+num2))
print('빼기 결과 : %d'%(num1-num2))
print('곱하기 결과 : %d'%(num1*num2))
print('나누기 결과 : %d'%(num1/num2))

# %% [markdown]
# #input()함수 사용

# %%
name = input()
# Out:
# 3

# %%
print(name)
# Out:
# 3

# %%
num = input("정수를 입력하세요 >> ")
print(num)
# Out:
# 정수를 입력하세요 >> 3
# 3

# %% [markdown]
# type(num)

# %%
num1 = int(input('첫번째 숫자를 입력하세요 >>'))
num2 = int(input('두번째 숫자를 입력하세요 >>'))
print('더하기 결과 :%d'%(num1+num2))
print('빼기 결과 :%d'%(num1-num2))
print('곱하기 결과 :%d'%(num1*num2))
print('나누기 결과 :%d'%(num1/num2))
# Out:
# 첫번째 숫자를 입력하세요 >>4
# 두번째 숫자를 입력하세요 >>5
# 더하기 결과 :9
# 빼기 결과 :-1
# 곱하기 결과 :20
# 나누기 결과 :0

# %%
score = int(input('python 점수 입력 >> '))
score1 = int(input('머신러닝 점수 입력 >> '))
score2 = int(input('딥러닝 점수 입력 >> '))
sum = score+score1+score2
print("합계 : {}".format(sum))
print("평균 : {}".format(sum/3))
# Out:
# python 점수 입력 >> 100
# 머신러닝 점수 입력 >> 80
# 딥러닝 점수 입력 >> 60
# 합계 : 240
# 평균 : 80.0

# %% [markdown]
# ### 지수연산자(**)

# %%
num = 3
power = 2
print(num**power)
# Out:
# 9

# %% [markdown]
# ## 대입(복합)연산자

# %%
a=3
b=7

# %%
temp=a
a=b
b=temp
print(a)
print(b)
# Out:
# 7
# 3

# %%
a, b = b, a
print(a)
print(b)
# Out:
# 7
# 3

# %% [markdown]
# ### 논리연산자

# %%
#not,and,or

# %%
a = 1
b = 5
print(1<5)
not a<b
# Out:
# True
# False

# %%
print(a)
a
b
# Out:
# 1
# 5
